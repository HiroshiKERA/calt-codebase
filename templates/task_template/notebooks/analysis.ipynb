# %% [markdown]
# # Task template — analysis notebook
#
# Replace this stub with task-specific exploration when you instantiate the template.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent.parent.parent))

# from <your_task>.core.generator import YourGenerator
# gen = YourGenerator(...)
# print(gen(seed=0))
